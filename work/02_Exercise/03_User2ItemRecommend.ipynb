# %% [markdown]
# # 課題3: User to Item Recommend
#
# アニメの配信サイトをイメージして、ログインしているあるユーザを起点としてアニメをレコメンドする機能をSQLで作成してください。 レコメンドを作成する際に、どのようなページでどのような行動を起こさせるためのレコメンドかも想定しながらロジックを検討してください。
#
# ## 例1
#
# ログインユーザに対して、過去の視聴履歴からおすすめのアニメを取得し、トップページに表示する
#
# ## 例2
#
# ログインユーザに対して、過去の視聴履歴から好みのジャンルを取得し、それぞれのジャンルについておすすめのアニメをトップページに表示する
#
# ## 例3
#
# ログインユーザに対して、高評価をつけたアニメを取得し、そのアニメの類似アニメをメールでおすすめする
#
# ## 例4
#
# ログインユーザに対して、過去の視聴履歴から傾向の似ている他のユーザを取得し、他の類似ユーザが視聴していて対象ログインユーザがまだ見ていないアニメをメールでおすすめする
#
# ## 手順
#
# animelistテーブルから対象ユーザを一人選択し、そのユーザを対象としたおすすめアニメをSQLで取得してください。
#
# 既存のユーザではなく、独自のユーザ（分析者自身など）を仮定したい場合は、任意のデータを追加したりクエリ上でアドホックなユーザを仮定しても構いません。
#
# ひとりのユーザに対してレコメンドするアイテムは、最大で100件程度とします。
#
# それぞれのSQLには、意図したクエリの説明文と、実行結果例を付与してください。SQLは、必要に応じて複数のセルに分けて記述しても構いません。
#
# 複数のアイデアがある場合は、回答を区切って複数提出しても構いません。
#
# ## ヒント
#
# - ユーザに対してアニメをおすすめする際、すでに視聴済みのアニメはレコメンドから除かれているほうが望ましいことが多いです
# - ユーザからおすすめアイテムを取得する方法として、「まずユーザの既知のアイテム群を取得し、そのアイテムに類似する未知のアイテムを取得する方法」（Item to Itemの応用や**アソシエーション分析**）と、「対象ユーザと類似するユーザ群を取得し、そのユーザ群が嗜好しているアイテムの中から未知のアイテムを取得する方法」（**協調フィルタリング**）があります
# - アソシエーション分析の古典的なアルゴリズムとして、**アプリオリ**アルゴリズムがあり、「アイテムの組み合わせ（A, B, C, ...）を買った人のn%は、アイテムの組み合わせ（X, Y, Z, ...）を買う」といった**相関ルール**を抽出できます
# - 相関ルールの評価指標として、**支持度（support）** や **確信度（confidence）**、 **リフト（lift）** などがあります。
# - 実用的に利用されているUser to Itemレコメンドの多くは、機械学習による反復計算や再帰計算が必要なアルゴリズムであり、SQLだけで実現するには不向きなため、SQLでは前処理だけを行い、レコメンドの計算はライブラリを利用するケースが多くあります。しかし、今回のワークショップでは、既存のライブラリの使い方を学ぶのではなく、ゼロから自身の手でレコメンドのアルゴリズムを理解することを目標としているため、SQLだけで実現できるロジックを考えてみてください。

# %%
# %load_ext dotenv
# %load_ext sql

# %%
import os
# %dotenv
dsl = f"postgresql://postgres:{os.environ.get('POSTGRES_PASSWORD')}@postgres:5432/postgres"
# %sql $dsl

# %%
# %%sql
